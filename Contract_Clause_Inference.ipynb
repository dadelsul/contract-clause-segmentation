# %% [markdown]
# # Contract Clause Segmentation – Inference Demo

# %%
print("Inference demo notebook is working")

# %%
git add Contract_Clause_Inference.ipynb
git commit -m "Fix inference notebook (valid ipynb)"
git push
